# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
prets = pd.read_csv('prets.csv')

# %%
prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %%
sns.scatterplot(data=prets, x='revenu', y='taux')
plt.show()

# %%
sns.scatterplot(data=prets, x='revenu', y='taux', hue='type')
plt.show()

# %%
sns.scatterplot(data=prets, x='revenu', y='taux', size='duree')
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.rcParams.update({'font.size': 14})

sns.scatterplot(data=prets, x='revenu', y='taux', hue='type')

plt.ylabel("Taux d'endettement")

plt.xlabel('Revenu mensuel (€)')

plt.grid()

plt.xlim(500, 7500)

plt.legend(bbox_to_anchor=(1, 1.02))

plt.title("Taux d'endettement en fonction du revenu mensuel\npar type de prêt contracté")

plt.show()

# %%
sns.barplot(data=prets, x='ville', y='remboursement', ci=None, estimator=sum)
sns.set_theme(style='whitegrid', palette='pastel')

# %%
sns.barplot(data=prets, x='ville', y='remboursement', ci=None, estimator=np.mean, hue='type')
plt.show()

# %%
benefTot = prets.groupby(['ville'])['revenu'].sum() 
benefTot = benefTot.reset_index()
benefTot
# Out:
#        ville    revenu
# 0   BORDEAUX   50816.0
# 1       LYON   95354.0
# 2  MARSEILLE  145926.0
# 3       NICE   85288.0
# 4      PARIS  335459.0
# 5   TOULOUSE   75617.0

# %%
plt.bar(height=benefTot['revenu'], x=benefTot['ville'])
sns.set_theme(style='whitegrid', palette='pastel')
plt.title("Les revenus par agence")
plt.xlabel("Les Agences")
plt.ylabel("Les revenus en euros")
plt.show()
