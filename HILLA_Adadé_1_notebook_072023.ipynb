# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import folium as fol

# %% [markdown]
# # Énoncé
#
# Dans ce challenge, ouvert à tous, vous allez réaliser une analyse exploratoire avec un jeu de données portant sur les arbres de la ville de Paris, dans le cadre du programme "Végétalisons la ville".
#
# Vos résultats contribueront à une optimisation des tournées pour l’entretien des arbres de la ville. Eh oui, moins de tournées signifie moins de trajets, et plus d’arbres entretenus.
#
# Vous aurez ainsi un impact réel sur le futur de la ville de Paris !

# %% [markdown]
# # 1. Présentation générale du jeu de données

# %%
arbres = pd.read_csv("arbres.csv", sep = ';', dtype=None, low_memory=False)
arbres.head(5)
# Out:
#       id type_emplacement domanialite   arrondissement complement_addresse  \
# 0  99874            Arbre      Jardin   PARIS 7E ARRDT                 NaN
# 1  99875            Arbre      Jardin   PARIS 7E ARRDT                 NaN
# 2  99876            Arbre      Jardin   PARIS 7E ARRDT                 NaN
# 3  99877            Arbre      Jardin   PARIS 7E ARRDT                 NaN
# 4  99878            Arbre      Jardin  PARIS 17E ARRDT                 NaN
#
#    numero                                        lieu id_emplacement  \
# 0     NaN   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             19
# 1     NaN   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             20
# 2     NaN   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             21
# 3     NaN   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             22
# 4     NaN  PARC CLICHY-BATIGNOLLES-MARTIN LUTHER KING       000G0037
#
#   libelle_francais      genre         espece variete  circonference_cm  \
# 0       Marronnier   Aesculus  hippocastanum     NaN              20.0
# 1               If      Taxus        baccata     NaN              65.0
# 2               If      Taxus        baccata     NaN              90.0
# 3           Erable       Acer        negundo     NaN              60.0
# 4     Arbre à miel  Tetradium      daniellii     NaN              38.0
#
#    hauteur_m stade_developpement  remarquable  geo_point_2d_a  geo_point_2d_b
# 0        5.0                 NaN          0.0       48.857620        2.320962
# 1        8.0                   A          NaN       48.857656        2.321031
# 2       10.0                   A          NaN       48.857705        2.321061
# 3        8.0                   A          NaN       48.857722        2.321006
# 4        0.0                 NaN          NaN       48.890435        2.315289

# %% [markdown]
# # 2. Inspection des données

# %%
arbres.shape
# Out:
# (200137, 18)

# %%
arbres.columns
# Out:
# Index(['id', 'type_emplacement', 'domanialite', 'arrondissement',
#        'complement_addresse', 'numero', 'lieu', 'id_emplacement',
#        'libelle_francais', 'genre', 'espece', 'variete', 'circonference_cm',
#        'hauteur_m', 'stade_developpement', 'remarquable', 'geo_point_2d_a',
#        'geo_point_2d_b'],
#       dtype='object')

# %%
arbres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200137 entries, 0 to 200136
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   200137 non-null  object
#  1   type_emplacement     200136 non-null  object
#  2   domanialite          200135 non-null  object
#  3   arrondissement       200136 non-null  object
#  4   complement_addresse  30901 non-null   object
#  5   numero               0 non-null       float64
#  6   lieu                 200136 non-null  object
#  7   id_emplacement       200136 non-null  object
#  8   libelle_francais     198639 non-null  object
#  9   genre                200120 non-null  object
#  10  espece               198384 non-null  object
#  11  variete              36777 non-null   object
#  12  circonference_cm     200136 non-null  float64
#  13  hauteur_m            200136 non-null  float64
#  14  stade_developpement  132932 non-null  object
#  15  remarquable          137038 non-null  float64
#  16  geo_point_2d_a       200136 non-null  float64
#  17  geo_point_2d_b       200136 non-null  float64
# dtypes: float64(6), object(12)
# memory usage: 27.5+ MB

# %% [markdown]
# Le nombre de variables manquantes dans notre dataframe listé par colonne

# %%
arbres.isnull().sum()
# Out:
# id                          0
# type_emplacement            1
# domanialite                 2
# arrondissement              1
# complement_addresse    169236
# numero                 200137
# lieu                        1
# id_emplacement              1
# libelle_francais         1498
# genre                      17
# espece                   1753
# variete                163360
# circonference_cm            1
# hauteur_m                   1
# stade_developpement     67205
# remarquable             63099
# geo_point_2d_a              1
# geo_point_2d_b              1
# dtype: int64

# %% [markdown]
#  - La matrice des données manquantes

# %%
msno.matrix(arbres)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Le diagramme à bandes

# %%
msno.bar(arbres)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Remarque : Les colonnes numeros, complement_addresse, variete, stade_developpement, remarquable sont inexploitables

# %% [markdown]
# - La carte de chaleur des données

# %%
msno.heatmap(arbres)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. Verification des doublons (nombre de ligne en double)

# %%
arbres.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Nous supprimons les colonnes inexploitables suivantes : numero, complement_addresse, variete, stade_developpement, et remarquable

# %%
arb_epur1 = arbres.drop(['numero', 'complement_addresse', 'stade_developpement', 'remarquable', 'variete'], axis=1)
arb_epur1
# Out:
#              id type_emplacement domanialite     arrondissement  \
# 0         99874            Arbre      Jardin     PARIS 7E ARRDT
# 1         99875            Arbre      Jardin     PARIS 7E ARRDT
# 2         99876            Arbre      Jardin     PARIS 7E ARRDT
# 3         99877            Arbre      Jardin     PARIS 7E ARRDT
# 4         99878            Arbre      Jardin    PARIS 17E ARRDT
# ...         ...              ...         ...                ...
# 200132  2024741            Arbre      Jardin  BOIS DE VINCENNES
# 200133  2024742            Arbre      Jardin  BOIS DE VINCENNES
# 200134  2024743            Arbre      Jardin  BOIS DE VINCENNES
# 200135  2024744            Arbre      Jardin  BOIS DE VINCENNES
# 200136  2024745            Arbre      Jardin  BOIS DE VINCENNES
#
#                                                      lieu id_emplacement  \
# 0               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             19
# 1               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             20
# 2               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             21
# 3               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             22
# 4              PARC CLICHY-BATIGNOLLES-MARTIN LUTHER KING       000G0037
# ...                                                   ...            ...
# 200132  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...      720170151
# 200133  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...      720170152
# 200134  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...      720170153
# 200135  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...      720170154
# 200136  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...      720170155
#
#            libelle_francais      genre         espece  circonference_cm  \
# 0                Marronnier   Aesculus  hippocastanum              20.0
# 1                        If      Taxus        baccata              65.0
# 2                        If      Taxus        baccata              90.0
# 3                    Erable       Acer        negundo              60.0
# 4              Arbre à miel  Tetradium      daniellii              38.0
# ...                     ...        ...            ...               ...
# 200132                  NaN   Castanea       fargesii               0.0
# 200133  Arbre aux mouchoirs    Davidia    involucrata               0.0
# 200134             Peuplier    Populus        simonii               0.0
# 200135                Chêne    Quercus         n. sp.               0.0
# 200136            Raisinier    Hovenia         dulcis               0.0
#
#         hauteur_m  geo_point_2d_a  geo_point_2d_b
# 0             5.0       48.857620        2.320962
# 1             8.0       48.857656        2.321031
# 2            10.0       48.857705        2.321061
# 3             8.0       48.857722        2.321006
# 4             0.0       48.890435        2.315289
# ...           ...             ...             ...
# 200132        0.0       48.821957        2.456264
# 200133        0.0       48.823254        2.457935
# 200134        0.0       48.822907        2.457970
# 200135        0.0       48.822522        2.455956
# 200136        0.0       48.820445        2.454856
#
# [200137 rows x 13 columns]

# %% [markdown]
# après suppression nous obtenons les diagrammes suivantes :

# %% [markdown]
# - Un diagramme à bande beaucoup plus rempli, il n'y a quasiment plus de données manquantes.

# %%
msno.bar(arb_epur1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - La nouvelle matrice de données manquantes

# %%
msno.matrix(arb_epur1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Le pourcentage de données manquantes dans chaque colonnes

# %%
pu =arbres.isna().mean()
pours_manq = pu * 100
pours_manq
# Out:
# id                       0.000000
# type_emplacement         0.000500
# domanialite              0.000999
# arrondissement           0.000500
# complement_addresse     84.560076
# numero                 100.000000
# lieu                     0.000500
# id_emplacement           0.000500
# libelle_francais         0.748487
# genre                    0.008494
# espece                   0.875900
# variete                 81.624088
# circonference_cm         0.000500
# hauteur_m                0.000500
# stade_developpement     33.579498
# remarquable             31.527903
# geo_point_2d_a           0.000500
# geo_point_2d_b           0.000500
# dtype: float64

# %% [markdown]
# Nous obtenons ici le nombre total d'arbre, la moyenne, le minimum, le maximum

# %%
arb_epur1.describe()
# Out:
#        circonference_cm      hauteur_m  geo_point_2d_a  geo_point_2d_b
# count     200136.000000  200136.000000   200136.000000   200136.000000
# mean          83.380796      13.110550       48.854491        2.348208
# std          673.191880    1971.222311        0.030234        0.051220
# min            0.000000       0.000000       48.742290        2.210241
# 25%           30.000000       5.000000       48.835021        2.307531
# 50%           70.000000       8.000000       48.854162        2.351096
# 75%          115.000000      12.000000       48.876447        2.386838
# max       250255.000000  881818.000000       48.911485        2.469759

# %% [markdown]
# # 3. Exploration des données

# %% [markdown]
# - La repatition par ordre croissant

# %%
tem = abr1 = arbres.groupby('arrondissement')['id'].count().reset_index()
abr1.columns = ['arrondissement','nombre']
temp = abr1.sort_values('nombre')
temp.head()
# Out:
#      arrondissement  nombre
# 15   PARIS 2E ARRDT     548
# 22   PARIS 9E ARRDT    1167
# 16   PARIS 3E ARRDT    1209
# 13  PARIS 1ER ARRDT    1413
# 19   PARIS 6E ARRDT    1764

# %%
temp['arrondissement'] = ['2e','9e','3e','1er','6e','5e', '4e','10e','BdB','HdS','11e','8e', 'VdM','7e','18e','17e ','14e','BdV','SsD','12e','19e','20e', '16e', '13e','15e']

# %%
tp1 = temp.iloc[0:14, :]
tp2 = temp.iloc[14:25,:]

# %% [markdown]
# - La repartition sur les arrondissements qui possèdent moins de 5% d'arbres sur le total des arbres sur la région parisienne.

# %%
plt.pie(x=tp1['nombre'], labels=tp1['arrondissement'],  radius=1.5, autopct='%.2f%%')
plt.show()

# %% [markdown]
# - La repartition sur les arrondissements qui possèdent plus de 5% d'arbres sur le total des arbres de la région parisienne.

# %%
plt.pie(x=tp2['nombre'], labels=tp2['arrondissement'], radius=1.5, autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(13,6))
sns.set_theme(style='whitegrid')
plt.bar(height=temp['nombre'], x=temp['arrondissement'])
plt.title("Les arbres/arrondissement de Paris")
plt.xlabel("Les arrondissements de Paris")
plt.ylabel("Nbr arbres")
plt.xticks(rotation= 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(temp['arrondissement'], temp['nombre'],marker='o', linestyle='-', color='blue')
plt.xlabel("Les arrondissements de Paris")
plt.xticks(rotation= 45)
plt.show()

# %%
plt.figure(figsize=(11,8))
sns.set_theme(style='whitegrid')
y_pos = np.arange(len(temp['arrondissement']))
plt.barh(y_pos, temp['nombre'], align='center')
plt.barh ( temp['arrondissement'] , width = 0.1 , height = 0.6 , left = None,) 
plt.xlabel("Le nombre d'arbres")
plt.ylabel("Paris")
plt.title("Le nombre d'arbres par arrondissement sur la ville de Paris")
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.barplot(x=temp['arrondissement'], y=temp['nombre'], palette="RdBu")
plt.xlabel('\nArrondissements', fontsize=10, color='#c0392b')
plt.ylabel("Nombre d'arbres \n", fontsize=10, color='#c0392b')
plt.title("Le nombre d'arbres par arrondissement de Paris", fontsize=15, color='#e74c3c')
plt.xticks(rotation= 45)
#plt.tight_layout()
plt.show()

# %% [markdown]
# - Le 15e arrondissement (Paris 15) possède le plus grand nombre d'arbres et le 2e arrondissement (Paris 02) enregistre le plus faible nombre d'arbres.

# %%
ccc=  arbres.drop(['numero','arrondissement','domanialite','id','type_emplacement','lieu','id_emplacement','libelle_francais','genre','espece','hauteur_m','geo_point_2d_a','geo_point_2d_b', 'complement_addresse', 'stade_developpement', 'remarquable', 'variete'], axis=1)
ccc
# Out:
#         circonference_cm
# 0                   20.0
# 1                   65.0
# 2                   90.0
# 3                   60.0
# 4                   38.0
# ...                  ...
# 200132               0.0
# 200133               0.0
# 200134               0.0
# 200135               0.0
# 200136               0.0
#
# [200137 rows x 1 columns]

# %%
ccc= ccc['circonference_cm']
ccc.sort_values()
ccc
# Out:
# 0         20.0
# 1         65.0
# 2         90.0
# 3         60.0
# 4         38.0
#           ...
# 200132     0.0
# 200133     0.0
# 200134     0.0
# 200135     0.0
# 200136     0.0
# Name: circonference_cm, Length: 200137, dtype: float64

# %%
cc = ccc.drop(ccc.loc[(ccc==0)].index)
cc.reset_index()
# Out:
#          index  circonference_cm
# 0            0              20.0
# 1            1              65.0
# 2            2              90.0
# 3            3              60.0
# 4            4              38.0
# ...        ...               ...
# 174265  198874              20.0
# 174266  198875              20.0
# 174267  198876              20.0
# 174268  198877              20.0
# 174269  198878              20.0
#
# [174270 rows x 2 columns]

# %%
cc = cc.value_counts()  
cc.head()
# Out:
# 20.0    9710
# 70.0    6780
# 60.0    6369
# 80.0    6206
# 50.0    6205
# Name: circonference_cm, dtype: int64

# %%
sns.boxplot(cc,x=cc)
plt.xlim(0, 1000)
plt.xticks([0,50,100,127,250,300,500,1000])
plt.xticks(rotation= 45)
plt.title('Boite à moustache de la circonférence des arbres')
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Boite à moustache de la circonférence des arbres')

# %%
hhh = arb_epur1['hauteur_m']
hhh
# Out:
# 0          5.0
# 1          8.0
# 2         10.0
# 3          8.0
# 4          0.0
#           ...
# 200132     0.0
# 200133     0.0
# 200134     0.0
# 200135     0.0
# 200136     0.0
# Name: hauteur_m, Length: 200137, dtype: float64

# %%
hh = hhh.drop(hhh.loc[(hhh==0)].index)
hh.reset_index()
# Out:
#          index  hauteur_m
# 0            0        5.0
# 1            1        8.0
# 2            2       10.0
# 3            3        8.0
# 4            7       17.0
# ...        ...        ...
# 160913  198874        5.0
# 160914  198875        5.0
# 160915  198876        5.0
# 160916  198877        5.0
# 160917  198878        5.0
#
# [160918 rows x 2 columns]

# %%
hh.describe()
# Out:
# count    160917.000000
# mean         16.305878
# std        2198.341576
# min           1.000000
# 25%           6.000000
# 50%          10.000000
# 75%          14.000000
# max      881818.000000
# Name: hauteur_m, dtype: float64

# %%
sns.boxplot(hh,x=hh)
plt.xlim(0, 100)
plt.xticks([0,5,10,15,20,30,40,50,100])
plt.title('Boite à moustache de la hauteur des arbres')
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Boite à moustache de la hauteur des arbres')

# %%
arb_epur1.isnull().sum()
# Out:
# id                     0
# type_emplacement       1
# domanialite            2
# arrondissement         1
# lieu                   1
# id_emplacement         1
# libelle_francais    1498
# genre                 17
# espece              1753
# circonference_cm       1
# hauteur_m              1
# geo_point_2d_a         1
# geo_point_2d_b         1
# dtype: int64

# %%
arb_epur1.head()
# Out:
#       id type_emplacement domanialite   arrondissement  \
# 0  99874            Arbre      Jardin   PARIS 7E ARRDT
# 1  99875            Arbre      Jardin   PARIS 7E ARRDT
# 2  99876            Arbre      Jardin   PARIS 7E ARRDT
# 3  99877            Arbre      Jardin   PARIS 7E ARRDT
# 4  99878            Arbre      Jardin  PARIS 17E ARRDT
#
#                                          lieu id_emplacement libelle_francais  \
# 0   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             19       Marronnier
# 1   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             20               If
# 2   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             21               If
# 3   MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E             22           Erable
# 4  PARC CLICHY-BATIGNOLLES-MARTIN LUTHER KING       000G0037     Arbre à miel
#
#        genre         espece  circonference_cm  hauteur_m  geo_point_2d_a  \
# 0   Aesculus  hippocastanum              20.0        5.0       48.857620
# 1      Taxus        baccata              65.0        8.0       48.857656
# 2      Taxus        baccata              90.0       10.0       48.857705
# 3       Acer        negundo              60.0        8.0       48.857722
# 4  Tetradium      daniellii              38.0        0.0       48.890435
#
#    geo_point_2d_b
# 0        2.320962
# 1        2.321031
# 2        2.321061
# 3        2.321006
# 4        2.315289

# %% [markdown]
# On souhaite savoir le nombre d'arbres par arrondissement de Paris

# %%
arbre_d = arbres.drop(['complement_addresse', 'numero', 'id_emplacement', 'variete', 'circonference_cm', 'remarquable', 'geo_point_2d_a', 'geo_point_2d_b'], axis=1)

# %%
arbre_d
# Out:
#              id type_emplacement domanialite     arrondissement  \
# 0         99874            Arbre      Jardin     PARIS 7E ARRDT
# 1         99875            Arbre      Jardin     PARIS 7E ARRDT
# 2         99876            Arbre      Jardin     PARIS 7E ARRDT
# 3         99877            Arbre      Jardin     PARIS 7E ARRDT
# 4         99878            Arbre      Jardin    PARIS 17E ARRDT
# ...         ...              ...         ...                ...
# 200132  2024741            Arbre      Jardin  BOIS DE VINCENNES
# 200133  2024742            Arbre      Jardin  BOIS DE VINCENNES
# 200134  2024743            Arbre      Jardin  BOIS DE VINCENNES
# 200135  2024744            Arbre      Jardin  BOIS DE VINCENNES
# 200136  2024745            Arbre      Jardin  BOIS DE VINCENNES
#
#                                                      lieu  \
# 0               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 1               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 2               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 3               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 4              PARC CLICHY-BATIGNOLLES-MARTIN LUTHER KING
# ...                                                   ...
# 200132  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200133  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200134  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200135  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200136  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
#
#            libelle_francais      genre         espece  hauteur_m  \
# 0                Marronnier   Aesculus  hippocastanum        5.0
# 1                        If      Taxus        baccata        8.0
# 2                        If      Taxus        baccata       10.0
# 3                    Erable       Acer        negundo        8.0
# 4              Arbre à miel  Tetradium      daniellii        0.0
# ...                     ...        ...            ...        ...
# 200132                  NaN   Castanea       fargesii        0.0
# 200133  Arbre aux mouchoirs    Davidia    involucrata        0.0
# 200134             Peuplier    Populus        simonii        0.0
# 200135                Chêne    Quercus         n. sp.        0.0
# 200136            Raisinier    Hovenia         dulcis        0.0
#
#        stade_developpement
# 0                      NaN
# 1                        A
# 2                        A
# 3                        A
# 4                      NaN
# ...                    ...
# 200132                 NaN
# 200133                 NaN
# 200134                 NaN
# 200135                 NaN
# 200136                 NaN
#
# [200137 rows x 10 columns]

# %%
arbre_d2 = arbre_d.drop(['arrondissement', 'genre', 'stade_developpement', 'domanialite', 'hauteur_m'], axis=1)

# %%
arbre_d2
# Out:
#              id type_emplacement  \
# 0         99874            Arbre
# 1         99875            Arbre
# 2         99876            Arbre
# 3         99877            Arbre
# 4         99878            Arbre
# ...         ...              ...
# 200132  2024741            Arbre
# 200133  2024742            Arbre
# 200134  2024743            Arbre
# 200135  2024744            Arbre
# 200136  2024745            Arbre
#
#                                                      lieu  \
# 0               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 1               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 2               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 3               MAIRIE DU 7E 116 RUE DE GRENELLE PARIS 7E
# 4              PARC CLICHY-BATIGNOLLES-MARTIN LUTHER KING
# ...                                                   ...
# 200132  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200133  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200134  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200135  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
# 200136  ARBORETUM DE L ECOLE DU BREUIL - ROUTE DE LA F...
#
#            libelle_francais         espece
# 0                Marronnier  hippocastanum
# 1                        If        baccata
# 2                        If        baccata
# 3                    Erable        negundo
# 4              Arbre à miel      daniellii
# ...                     ...            ...
# 200132                  NaN       fargesii
# 200133  Arbre aux mouchoirs    involucrata
# 200134             Peuplier        simonii
# 200135                Chêne         n. sp.
# 200136            Raisinier         dulcis
#
# [200137 rows x 5 columns]

# %%
arbre_d3 = arbre_d2.dropna(axis=0)

# %%
arbre_d3.shape
# Out:
# (197252, 5)

# %%
arbre_d3.describe()
# Out:
#             id type_emplacement                                         lieu  \
# count   197252           197252                                       197252
# unique  197252                1                                         6876
# top      99874            Arbre  PARC FLORAL DE PARIS / ROUTE DE LA PYRAMIDE
# freq         1           197252                                         2983
#
#        libelle_francais       espece
# count            197252       197252
# unique              191          520
# top             Platane  x hispanica
# freq              42505        36242

# %%
arbre_d3['libelle_francais'].value_counts()
# Out:
# Platane       42505
# Marronnier    25207
# Tilleul       21305
# Erable        18389
# Sophora       11797
#               ...
# Maackie           1
# Jujubier          1
# Camphrier         1
# Sycopsis          1
# Garrya            1
# Name: libelle_francais, Length: 191, dtype: int64

# %%
vue=arbres.groupby(['arrondissement','lieu','genre']) ['circonference_cm'].max()
vue.head(49)
# Out:
# arrondissement    lieu                          genre
# BOIS DE BOULOGNE  ALLEE DE LA REINE MARGUERITE  Acer            160.0
#                                                 Aesculus        220.0
#                                                 Celtis           80.0
#                                                 Gleditsia       120.0
#                                                 Malus            44.0
#                                                 Ostrya           20.0
#                                                 Pinus            60.0
#                                                 Platanus        210.0
#                                                 Prunus           60.0
#                                                 Pterocarya      195.0
#                                                 Quercus          28.0
#                                                 Sophora         140.0
#                                                 Sorbus           19.0
#                                                 Tilia           200.0
#                                                 Ulmus            90.0
#                                                 Zelkova         200.0
#                   ALLEE DE LONGCHAMP            Acer             33.0
#                                                 Aesculus        215.0
#                                                 Carpinus         20.0
#                                                 Corylus          90.0
#                                                 Ostrya           17.0
#                                                 Pinus            15.0
#                                                 Platanus         25.0
#                                                 Prunus           28.0
#                                                 Sophora         165.0
#                                                 Sorbus           26.0
#                                                 Tilia            33.0
#                                                 Ulmus            37.0
#                   ALLEE DES FORTIFICATIONS      Acer             75.0
#                                                 Aesculus        280.0
#                                                 Carpinus         25.0
#                                                 Fraxinus          0.0
#                                                 Non spécifié      0.0
#                                                 Pinus            15.0
#                                                 Platanus          0.0
#                                                 Prunus           55.0
#                                                 Pterocarya        0.0
#                                                 Tilia           210.0
#                                                 Zelkova          80.0
#                   ALLEE DU BORD DE L EAU        Aesculus          0.0
#                                                 Platanus         20.0
#                   AVENUE ANATOLE FRANCE         Aesculus        235.0
#                   AVENUE DE L HIPPODROME        Platanus        425.0
#                   AVENUE DE SAINT CLOUD         Acer             69.0
#                                                 Aesculus        213.0
#                                                 Pinus            15.0
#                                                 Platanus         96.0
#                                                 Tilia            69.0
#                                                 Ulmus            95.0
# Name: circonference_cm, dtype: float64

# %%
vue.tail()
# Out:
# arrondissement  lieu                                                    genre
# VAL-DE-MARNE    CIMETIERE DE THIAIS / AVENUE TRANSVERSALE N3 / DIV 122  Platanus      0.0
#                 CIMETIERE DE THIAIS / DIV 94                            Malus        20.0
#                 CIMETIERE DE THIAIS / ENTREE NORD                       Acer        145.0
#                 CIMETIERE DE THIAIS / ENTREE PRINCIPALE                 Albizia      20.0
#                                                                         Cedrus       20.0
# Name: circonference_cm, dtype: float64

# %%
vue
# Out:
# arrondissement    lieu                                                    genre
# BOIS DE BOULOGNE  ALLEE DE LA REINE MARGUERITE                            Acer         160.0
#                                                                           Aesculus     220.0
#                                                                           Celtis        80.0
#                                                                           Gleditsia    120.0
#                                                                           Malus         44.0
#                                                                                        ...
# VAL-DE-MARNE      CIMETIERE DE THIAIS / AVENUE TRANSVERSALE N3 / DIV 122  Platanus       0.0
#                   CIMETIERE DE THIAIS / DIV 94                            Malus         20.0
#                   CIMETIERE DE THIAIS / ENTREE NORD                       Acer         145.0
#                   CIMETIERE DE THIAIS / ENTREE PRINCIPALE                 Albizia       20.0
#                                                                           Cedrus        20.0
# Name: circonference_cm, Length: 19015, dtype: float64

# %%
c = fol.Map(location=[ 48.890, 2.315333],zoom_start=25)
fol.Marker([48.890435, 2.315289]).add_to(c)
c.save('maCarte3.html')

# %%
c = fol.Map(location=[ 48.890, 2.315333],zoom_start=25)
fol.Marker([48.890435, 2.315289],popup="fofo").add_to(c)
fol.Marker([48.820445, 2.454856],popup="édédé ").add_to(c)
c.save('maCarte4.html')
