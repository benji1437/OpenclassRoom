# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arbres = pd.read_csv('arbres.csv')

# %%
arbres.columns
# Out:
# Index(['id;type_emplacement;domanialite;arrondissement;complement_addresse;numero;lieu;id_emplacement;libelle_francais;genre;espece;variete;circonference_cm;hauteur_m;stade_developpement;remarquable;geo_point_2d_a;geo_point_2d_b'], dtype='object')

# %%
vue_arb = arbres
print(vue_arb)
# Out:
#        id;type_emplacement;domanialite;arrondissement;complement_addresse;numero;lieu;id_emplacement;libelle_francais;genre;espece;variete;circonference_cm;hauteur_m;stade_developpement;remarquable;geo_point_2d_a;geo_point_2d_b
# 0       99874;Arbre;Jardin;PARIS 7E ARRDT;;;MAIRIE DU ...
# 1       99875;Arbre;Jardin;PARIS 7E ARRDT;;;MAIRIE DU ...
# 2       99876;Arbre;Jardin;PARIS 7E ARRDT;;;MAIRIE DU ...
# 3       99877;Arbre;Jardin;PARIS 7E ARRDT;;;MAIRIE DU ...
# 4       99878;Arbre;Jardin;PARIS 17E ARRDT;;;PARC CLIC...
# ...                                                   ...
# 200132  2024741;Arbre;Jardin;BOIS DE VINCENNES;;;ARBOR...
# 200133  2024742;Arbre;Jardin;BOIS DE VINCENNES;;;ARBOR...
# 200134  2024743;Arbre;Jardin;BOIS DE VINCENNES;;;ARBOR...
# 200135  2024744;Arbre;Jardin;BOIS DE VINCENNES;;;ARBOR...
# 200136  2024745;Arbre;Jardin;BOIS DE VINCENNES;;;ARBOR...
#
# [200137 rows x 1 columns]

# %%
tita = pd.read_excel('titanic.xls')
tita.head(25)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
tita.shape
# Out:
# (1309, 14)

# %%
tita.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
tita
# Out:
#       pclass  survived     sex      age                        home.dest
# 0          1         1  female  29.0000                     St Louis, MO
# 1          1         1    male   0.9167  Montreal, PQ / Chesterville, ON
# 2          1         0  female   2.0000  Montreal, PQ / Chesterville, ON
# 3          1         0    male  30.0000  Montreal, PQ / Chesterville, ON
# 4          1         0  female  25.0000  Montreal, PQ / Chesterville, ON
# ...      ...       ...     ...      ...                              ...
# 1304       3         0  female  14.5000                              NaN
# 1305       3         0  female      NaN                              NaN
# 1306       3         0    male  26.5000                              NaN
# 1307       3         0    male  27.0000                              NaN
# 1308       3         0    male  29.0000                              NaN
#
# [1309 rows x 5 columns]

# %%
tita = tita.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8896\164006593.py in <module>
# ----> 1 tita = tita.drop(['name', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
tita.tail(25)
# Out:
#       pclass  survived     sex   age home.dest
# 1284       3         0    male   NaN       NaN
# 1285       3         0    male  32.5       NaN
# 1286       3         1  female  38.0       NaN
# 1287       3         0    male  51.0       NaN
# 1288       3         0    male  18.0       NaN
# 1289       3         0    male  21.0       NaN
# 1290       3         1  female  47.0       NaN
# 1291       3         0    male   NaN       NaN
# 1292       3         0    male   NaN       NaN
# 1293       3         0    male   NaN       NaN
# 1294       3         0    male  28.5       NaN
# 1295       3         0    male  21.0       NaN
# 1296       3         0    male  27.0       NaN
# 1297       3         0    male   NaN       NaN
# 1298       3         0    male  36.0       NaN
# 1299       3         0    male  27.0       NaN
# 1300       3         1  female  15.0       NaN
# 1301       3         0    male  45.5       NaN
# 1302       3         0    male   NaN       NaN
# ...

# %%
tita.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
titad = tita.drop(['home.dest'], axis=1)

# %%
titad
# Out:
#       pclass  survived     sex      age
# 0          1         1  female  29.0000
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 3          1         0    male  30.0000
# 4          1         0  female  25.0000
# ...      ...       ...     ...      ...
# 1304       3         0  female  14.5000
# 1305       3         0  female      NaN
# 1306       3         0    male  26.5000
# 1307       3         0    male  27.0000
# 1308       3         0    male  29.0000
#
# [1309 rows x 4 columns]

# %%
titad.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
tit = titad.dropna(axis=0)

# %%
tit.shape
# Out:
# (1046, 4)

# %%
tit.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
titA = tit['pclass'].value_counts().plot.bar()
plt.show()

# %%
tit['age'].hist()
plt.show()

# %%
plt.scatter(tit['age'], tit['pclass'], c='green')
plt.title("La répartition des âges par classe de cabine")
plt.show()
